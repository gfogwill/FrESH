# %%
# %load_ext autoreload
# %autoreload 2
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
from src.daq import mccdaq
from src.daq.IniLoader import IniLoader

# %%
daq = mccdaq.Daq()

daq.set_starting_temp(init_temp)
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[12], line 1
# ----> 1 daq = mccdaq.Daq()
#       3 daq.set_starting_temp(init_temp)
#
# File ~/PycharmProjects/icenucleicounter/src/daq/mccdaq.py:17, in Daq.__init__(self)
#      14 devices = get_daq_device_inventory(InterfaceType.USB)
#      16 # Create a DaqDevice Object and connect to the device
# ---> 17 self.daq_device = DaqDevice(devices[0])
#      18 self.daq_device.connect()
#      20 # Get AoDevice and AoInfo objects for the analog input subsystem
#
# IndexError: list index out of range

# %%
daq.ai.a_in(channel=5,
            input_mode=AiInputMode.DIFFERENTIAL,
            analog_range=Range.BIP10VOLTS,
            flags=AInFlag.DEFAULT)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[11], line 1
# ----> 1 daq.ai.a_in(channel=5,
#       2             input_mode=AiInputMode.DIFFERENTIAL,
#       3             analog_range=Range.BIP10VOLTS,
#       4             flags=AInFlag.DEFAULT)
#
# NameError: name 'daq' is not defined
